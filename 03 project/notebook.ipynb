# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Start coding here!

# %%
# creating dataframe
df = pd.read_csv("data/nobel.csv")
df.head()
# Out:
#    year    category  ... death_city death_country
# 0  1901   Chemistry  ...     Berlin       Germany
# 1  1901  Literature  ...   Châtenay        France
# 2  1901    Medicine  ...    Marburg       Germany
# 3  1901       Peace  ...     Heiden   Switzerland
# 4  1901       Peace  ...      Paris        France
#
# [5 rows x 18 columns]

# %%
sns.set_context("paper")
sns.catplot(x = "sex", data = df , kind = "count", col = "birth_country", col_wrap = 4 )

plt.show()

# %%
top_gender = "Male"
top_country = "United States of America"

# %%
df2 = df[df["birth_country"] == "United States of America"]
df2
# Out:
#      year   category  ...      death_city             death_country
# 35   1906      Peace  ...  Oyster Bay, NY  United States of America
# 72   1912      Peace  ...    New York, NY  United States of America
# 79   1914  Chemistry  ...   Cambridge, MA  United States of America
# 95   1919      Peace  ...  Washington, DC  United States of America
# 117  1923    Physics  ...  San Marino, CA  United States of America
# ..    ...        ...  ...             ...                       ...
# 987  2022  Economics  ...             NaN                       NaN
# 988  2022  Economics  ...             NaN                       NaN
# 990  2023   Medicine  ...             NaN                       NaN
# 995  2023  Chemistry  ...             NaN                       NaN
# 999  2023  Economics  ...             NaN                       NaN
#
# [291 rows x 18 columns]

# %%
sns.set_style("whitegrid")
sns.catplot(y = "year", x = "prize_share", data = df2, kind = "point" ,palette = "RdBu", join = False)
plt.show()

# %%
max_decade_usa = 2000

# %%
sns.set_style("whitegrid")
sns.catplot(x = "sex", y = "year",data = df, kind = "point", palette = "RdBu", hue = "category", join = False, ci = None)
plt.show()
fem = df.query("year > 2010 and sex == 'Female'")
fem
# Out:
#      year    category  ...     death_city             death_country
# 847  2011       Peace  ...            NaN                       NaN
# 848  2011       Peace  ...            NaN                       NaN
# 849  2011       Peace  ...            NaN                       NaN
# 869  2013  Literature  ...            NaN                       NaN
# 882  2014    Medicine  ...            NaN                       NaN
# 885  2014       Peace  ...            NaN                       NaN
# 893  2015  Literature  ...            NaN                       NaN
# 896  2015    Medicine  ...            NaN                       NaN
# 927  2018     Physics  ...            NaN                       NaN
# 928  2018   Chemistry  ...            NaN                       NaN
# 932  2018       Peace  ...            NaN                       NaN
# 935  2018  Literature  ...            NaN                       NaN
# 948  2019   Economics  ...            NaN                       NaN
# ...

# %%
max_female_dict = {2020 : "Literature"}

# %%
sns.relplot(x = "laureate_id", y = "year", data = df, kind = "scatter" , hue = "category", col = "sex", 
           palette = ["red", "blue", "black", "yellow", "green", "gray"])
plt.show()

# %%
# Ensure 'birth_date' is in datetime format
r = df.query("sex == 'Female' and 1900 < year < 1910")
r
# Out:
#     year    category  ...  death_city death_country
# 19  1903     Physics  ...  Sallanches        France
# 29  1905       Peace  ...      Vienna       Austria
# 51  1909  Literature  ...    Mårbacka        Sweden
#
# [3 rows x 18 columns]

# %%
first_woman_name = "Marie Curie, née Sklodowska"
first_woman_category = "Physics"

# %%
df["full_name"].value_counts()
repeat_list = ["Comité international de la Croix Rouge (International Committee of the Red Cross)","Linus Carl Pauling","John Bardeen","Frederick Sanger","Marie Curie, née Sklodowska","Office of the United Nations High Commissioner for Refugees (UNHCR)"]
